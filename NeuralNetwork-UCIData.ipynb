# %%
import pandas as pd
import numpy as np 
from sklearn import preprocessing
from sklearn.naive_bayes import BernoulliNB, GaussianNB, MultinomialNB

# %%
df = pd.read_csv('C:/Users/ACER/Desktop/Data Science/ICT/dataset/labor-neg.data.csv',header = None)
df.columns=['duration','wage1','wage2','wage3','cola','hrs','pension','standby_pay','shift_differential','edu_allowance','holidays','vacation','disability_support',
                         'dental_plan','bereavement','health_plan','class_distribution']
df=df.replace('?', '')

# I will drop standby_pay attribute because of its few data entries, which do not sufficiently provide any useful input for discovery
df=df.drop(['standby_pay'],axis = 1)

# %% [markdown]
# ### Duration = 1 means that the employee receives only wage1. Duration = 2 means that the employee receives wage1, wage2. Duration = 3 means employees receives wage1,2,3

# %%
df.wage2 = df.wage2.replace('',0)
df.wage3 = df.wage3.replace('',0)

# %%
for i in range(0,len(df.index)):
    if(df.wage3[i] == '' and df.duration[i] == '1' or df.duration[i] == '2'):
        df.wage3[i] == '0'
    elif (df.wage3[i] == '' and df.duration[i] == '3'):
        df.wage3[i] == df.wage3.mean()

# %% [markdown]
# ### Employees who work for more than 38 hours/week will be less likely to receive education allowance because they will not have time to study. Therefore, we will fill education allowance missing values for employees who work for more than 38 hours/week as no, vice versa.

# %%
df.hrs = pd.to_numeric(df.hrs)
hrs_mean = int(df.hrs.mean())

# %%
df.hrs = pd.to_numeric(df.hrs)
df.hrs = df.hrs.replace(np.nan, hrs_mean)
for i in range(0, len(df.index)):
    if(df.loc[i,'edu_allowance'] == '' and df.hrs[i] >= 38):
        df.loc[i, 'edu_allowance'] = 'yes'
        df.edu_allowance[i] = "yes"
    elif (df.loc[i,'edu_allowance'] == '' and df.hrs[i] < 38):
        df.loc[i,'edu_allowance'] = 'no'


# df.edu_allowance = df.edu_allowance.replace('',df.edu_allowance.mode().iloc[0])    
# for i in range(0,len(df.index)):
#     if(df.edu_allowance[i] == 'no' and df.hrs[i] == ''):
#             df.loc[i,'hrs'] = 38
#     elif (df.edu_allowance[i] == 'yes' and df.hrs[i] == ''):
#            df.loc[i,'hrs'] = df.int(pf.to_numeric(df.hrs)).mean()
# Out:
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### We notice that if there is bereavement leave, there is a high chance that the company will also provide disability support because I believe that having disability support indicates that the company sympathizes and emphasizes the importance of mental health, hence, offers bereavement leave

# %%
df.bereavement = df.bereavement.replace('', (df[df['bereavement']!='']).bereavement.mode().iloc[0])

for i in range(0,len(df.index)):
   if df.loc[i,'disability_support'] == '':
      df.disability_support[i] = df.bereavement[i]
        
for i in range(0, len(df.index)):
    if df.loc[i,'dental_plan'] == '' and df.loc[i,'health_plan']!= '':
        df.dental_plan[i] = df.health_plan[i]
    elif df.loc[i, 'health_plan']=='' and df.loc[i,'dental_plan']!='':
        df.health_plan[i] = df.dental_plan[i]

df.dental_plan = df.dental_plan.replace('', (df[df['dental_plan']!='']).dental_plan.mode().iloc[0])
for i in range(0,len(df.index)):
   if df.loc[i,'disability_support'] == '':
      df.disability_support[i] = df.bereavement[i]
        
for i in range(0, len(df.index)):
    if df.loc[i,'dental_plan'] == '' and df.loc[i,'health_plan']!= '':
        df.dental_plan[i] = df.health_plan[i]
    elif df.loc[i, 'health_plan']=='' and df.loc[i,'dental_plan']!='':
        df.health_plan[i] = df.dental_plan[i]
# Out:
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel\__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel\__main__.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### We will use mode and mean to fill values in for vacation, shift differential, and holidays respectively.

# %%
type(df['hrs'].mode().iloc[0])
df[df['vacation']!=''].vacation.mode().iloc[0]
# Out:
# 'below average'

# %%
vacation_mode = df[df['vacation']!=''].vacation.mode().iloc[0]
df.vacation = df.vacation.replace('',vacation_mode)

df.shift_differential = pd.to_numeric(df.shift_differential) 
df.holidays = pd.to_numeric(df.holidays)
mean_shift = (df[df.shift_differential != np.nan]).shift_differential.mean()
df.shift_differential = df.shift_differential.fillna(int(mean_shift))
df.holidays = df.holidays.fillna(int(df.holidays.mean()))

# %% [markdown]
# ### I see that there is a relationsip between pension and vacation. There exists a pattern where if vacation is generous, then pension is empl_contr. If vacation is average , then pension is ret_allw. And if vacation is below average, then pension is none. A company provides employees pension means the company cares about the welfare, physical and mental health of the employees. Hence, I conclude this relationship.

# %%
for i in range(0, len(df.index)):
    if df.loc[i, 'pension'] == '' and df.loc[i,'vacation'] == 'generous':
        df.loc[i,'pension'] = 'empl_contr'
    elif df.loc[i,'pension'] == '' and df.loc[i,'vacation'] == 'average':
        df.loc[i,'pension'] = 'ret_allw'
    elif df.loc[i, 'pension'] == '' and df.loc[i, 'vacation'] == 'below average':
        df.loc[i, 'pension'] = 'none'

# %% [markdown]
# ### In the remaining two attributes, I do not see a specific relationship between them and other attributes. Hence, I will be using Naive Bayes to pre-process the data for cola, which is categorical variable.

# %%
cols1 = list(df.columns)
cols1.remove('duration')
cols1.remove('pension')
cols1.remove('hrs')
cols1.remove('class_distribution')

df2 = df[df.cola != '']
df.drop(df.index[2])
df2 = df2[cols1]

train_gau = df2[['wage1','wage2','wage3','shift_differential','holidays']].values

train_multi = pd.get_dummies(df2[['vacation','dental_plan','health_plan']]).values

train_be = df2[['edu_allowance','disability_support','bereavement']]
train_be[train_be == "yes"] = 1
train_be[train_be == "no"] = 0
train_be = train_be.values
lb = preprocessing.LabelBinarizer()
lb.fit(['yes','no'])

label = df2[['cola']].values



clf1 = GaussianNB()
clf2 = BernoulliNB(fit_prior=False)
clf3 = MultinomialNB(fit_prior=False)

clf1.fit(train_gau,label)
clf2.fit(train_be,label)
clf3.fit(train_multi,label)

def predict(gau,ber,multi):
    x1 = clf1.predict_proba(gau)
    x2 = clf2.predict_proba(ber)
    x3 = clf3.predict_proba(multi)
    result = x1[0] * x2[0] * x3[0]
    probmax = max(result)
    if probmax == result[0]:
        return clf1.classes_[0]
    if probmax == result[1]:
        return clf1.classes_[1]
    return clf1.classes_[2]

for i in range(0,len(df.index)):
    try:
        if df.cola[i] == '':
            gau = (df[['wage1','wage2','wage3','shift_differential','holidays']].values)[i]     
            
            ber = lb.transform((df[['edu_allowance','disability_support','bereavement']].values)[i])
            ber = np.array([ber[0][0],ber[1,0],ber[2,0]])
            
            multi = pd.get_dummies(df[list(['vacation','dental_plan','health_plan'])])
            columns = pd.get_dummies(df2[list(['vacation','dental_plan','health_plan'])]).columns
            multi = multi[columns].values
            
            df.cola[i] = predict(gau,ber,multi)
    except Exception as ex:
        continue
  
df = df.drop(df.index[2])
df
# Out:
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel\__main__.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ACER\Anaconda3\lib\site-packages\pandas\core\frame.py:2454: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._where(-key, value, inplace=True)
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel\__main__.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel\__main__.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
#    duration wage1 wage2 wage3  cola   hrs     pension  shift_differential  \
# 0         1     5     0     0  none  40.0    ret_allw                 2.0
# 1         2   4.5   5.8     0  none  35.0    ret_allw                 4.0
# 3         3   3.7     4     5    tc  38.0        none                 4.0
# 4         3   4.5   4.5     5   tcf  40.0    ret_allw                 4.0
# 5         2     2   2.5     0  none  35.0    ret_allw                 6.0
# 6         3     4     5     5    tc  38.0  empl_contr                 4.0
# 7         3   6.9   4.8   2.3  none  40.0        none                 3.0
# 8         2     3     7     0  none  38.0        none                25.0
# 9         1   5.7     0     0  none  40.0  empl_contr                 4.0
# 10        3   3.5     4   4.6  none  36.0  empl_contr                 3.0
# 11        2   6.4   6.4     0   tcf  38.0        none                 4.0
# 12        2   3.5     4     0  none  40.0        none                 2.0
# 13        3   3.5     4   5.1   tcf  37.0  empl_contr                 4.0
# 14        1     3     0     0  none  36.0  empl_contr                10.0
# 15        2   4.5     4     0  none  37.0  empl_contr                 4.0
# 16        1   2.8     0     0  none  35.0        none                 2.0
# 17        1   2.1     0     0    tc  40.0    ret_allw                 3.0
# 18        1     2     0     0  none  38.0        none                 4.0
# 19        2     4     5     0   tcf  35.0  empl_contr                 5.0
# 20        2   4.3   4.4     0  none  38.0  empl_contr                 4.0
# 21        2   2.5     3     0  none  40.0        none                 4.0
# 22        3   3.5     4   4.6   tcf  27.0        none                 4.0
# 23        2   4.5     4     0  none  40.0  empl_contr                 4.0
# 24        1     6     0     0  none  38.0  empl_contr                 3.0
# 25        3     2     2     2  none  40.0        none                 4.0
# 26        2   4.5   4.5     0   tcf  38.0        none                 4.0
# 27        2     3     3     0  none  33.0  empl_contr                 4.0
# 28        2     5     4     0  none  37.0        none                 5.0
# 29        3     2   2.5     0  none  35.0        none                 4.0
# 30        3   4.5   4.5     5  none  40.0    ret_allw                 4.0
# 31        3     3     2   2.5    tc  40.0        none                 5.0
# 32        2   2.5   2.5     0  none  38.0  empl_contr                 4.0
# 33        2     4     5     0  none  40.0        none                 3.0
# 34        3     2   2.5   2.1    tc  40.0        none                 1.0
# 35        2     2     2     0  none  40.0        none                 4.0
# 36        1     2     0     0    tc  40.0    ret_allw                 0.0
# 37        1   2.8     0     0  none  38.0  empl_contr                 3.0
# 38        3     2   2.5     2  none  37.0  empl_contr                 4.0
# 39        2   4.5     4     0  none  40.0    ret_allw                 4.0
# 40        1     4     0     0  none  38.0        none                 4.0
# 41        2     2     3     0  none  38.0  empl_contr                 4.0
# 42        2   2.5   2.5     0    tc  39.0  empl_contr                 4.0
# 43        2   2.5     3     0   tcf  40.0        none                 4.0
# 44        2     4     4     0  none  40.0        none                 3.0
# 45        2   4.5     4     0  none  40.0        none                 2.0
# 46        2   4.5     4     0  none  40.0    ret_allw                 5.0
# 47        2   4.6   4.6     0   tcf  38.0        none                 4.0
# 48        2     5   4.5     0  none  38.0        none                 5.0
# 49        2   5.7   4.5     0  none  40.0    ret_allw                 4.0
# 50        2     7   5.3     0  none  38.0        none                 4.0
# 51        3     2     3     0   tcf  38.0  empl_contr                 4.0
# 52        3   3.5     4   4.5   tcf  35.0  empl_contr                 4.0
# 53        3     4   3.5     0  none  40.0  empl_contr                 6.0
# 54        3     5   4.4     0  none  38.0  empl_contr                 6.0
# 55        3     5     5     5   tcf  40.0    ret_allw                 4.0
# 56        3     6     6     4  none  35.0  empl_contr                14.0
#
#    edu_allowance  holidays       vacation disability_support dental_plan  \
# 0            yes      11.0        average                yes        full
# 1            yes      11.0  below average                yes        full
# 3            yes      11.0  below average                yes        full
# 4            yes      12.0        average                yes        half
# 5            yes      12.0        average                yes        full
# 6            yes      12.0       generous                yes        none
# 7            yes      12.0  below average                yes        full
# 8            yes      11.0  below average                yes        half
# 9            yes      11.0       generous                yes        full
# 10            no      13.0       generous                yes        full
# 11           yes      15.0  below average                yes        full
# 12            no      10.0  below average                 no        half
# 13            no      13.0       generous                yes        full
# 14            no      11.0       generous                yes        full
# 15            no      11.0        average                yes        full
# 16            no      12.0  below average                yes        full
# 17            no       9.0  below average                yes        half
# 18           yes      11.0        average                 no        none
# 19            no      15.0       generous                yes        full
# 20           yes      12.0       generous                yes        full
# 21           yes      11.0  below average                yes        full
# 22            no      11.0  below average                yes        full
# 23           yes      10.0       generous                yes        half
# 24           yes       9.0       generous                yes        full
# 25           yes      10.0  below average                yes        half
# 26           yes      10.0  below average                yes        none
# 27           yes      12.0       generous                yes        full
# 28            no      11.0  below average                yes        full
# 29            no      10.0        average                yes        full
# 30            no      11.0        average                yes        half
# 31            no      10.0  below average                yes        half
# 32           yes      10.0        average                yes        full
# 33            no      10.0  below average                 no        none
# 34            no      10.0  below average                 no        half
# 35            no      11.0        average                yes        none
# 36            no      11.0       generous                 no        none
# 37            no       9.0  below average                yes        half
# 38            no      10.0        average                yes        none
# 39           yes      12.0        average                yes        full
# 40           yes      11.0        average                 no        none
# 41           yes      12.0       generous                yes        none
# 42           yes      12.0        average                yes        full
# 43           yes      11.0  below average                yes        full
# 44           yes      10.0  below average                 no        none
# 45            no      10.0  below average                 no        half
# 46           yes      11.0        average                yes        full
# 47           yes      11.0  below average                yes        half
# 48           yes      11.0  below average                yes        full
# 49           yes      11.0        average                yes        full
# 50           yes      11.0  below average                yes        full
# 51           yes      11.0  below average                yes        half
# 52            no      13.0       generous                yes        full
# 53           yes      11.0        average                yes        full
# 54           yes      11.0       generous                yes        full
# 55           yes      12.0        average                yes        half
# 56            no       9.0       generous                yes        full
#
#    bereavement health_plan class_distribution
# 0          yes        full               good
# 1          yes        full               good
# 3          yes        full               good
# 4          yes        half               good
# 5          yes        full               good
# 6          yes        half               good
# 7          yes        full               good
# 8          yes        half               good
# 9          yes        full               good
# 10         yes        full               good
# 11         yes        full               good
# 12         yes        half                bad
# 13         yes        full               good
# 14         yes        full               good
# 15         yes        full               good
# 16         yes        full               good
# 17         yes        none                bad
# 18          no        none                bad
# 19         yes        full               good
# 20         yes        full               good
# 21         yes        full                bad
# 22         yes        full               good
# 23         yes        full               good
# 24         yes        full               good
# 25         yes        full                bad
# 26         yes        half               good
# 27         yes        full               good
# 28         yes        full               good
# 29         yes        full                bad
# 30         yes        half               good
# 31         yes        full                bad
# 32         yes        full                bad
# 33         yes        none                bad
# 34         yes        full                bad
# 35         yes        full                bad
# 36          no        none                bad
# 37         yes        none                bad
# 38         yes        none                bad
# 39         yes        half               good
# 40          no        none                bad
# 41         yes        full                bad
# 42         yes        full                bad
# 43         yes        full                bad
# 44         yes        none                bad
# 45         yes        half                bad
# 46         yes        full               good
# 47         yes        half               good
# 48         yes        full               good
# 49         yes        full               good
# 50         yes        full               good
# 51         yes        half               good
# 52         yes        full               good
# 53         yes        full               good
# 54         yes        full               good
# 55         yes        half               good
# 56         yes        full               good

# %%
from sklearn.neural_network import MLPClassifier
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
le = preprocessing.LabelEncoder()

# %%
#Using dummies to encode 2-value attributes:
dummies_data = pd.get_dummies(df[['bereavement','disability_support']])
categorical_data = df[['vacation','dental_plan','health_plan','pension']]
continuous_data = df[['wage1', 'wage2', 'wage3','shift_differential','holidays']]
_class_distribution = df.class_distribution

#Using Label Encoder to give numerical values to values to attributes:
categorical_data = categorical_data.apply(le.fit_transform)
train = pd.concat([dummies_data, categorical_data,continuous_data], axis=1)
train.head(57)
# Out:
#     bereavement_no  bereavement_yes  disability_support_no  \
# 0                0                1                      0
# 1                0                1                      0
# 3                0                1                      0
# 4                0                1                      0
# 5                0                1                      0
# 6                0                1                      0
# 7                0                1                      0
# 8                0                1                      0
# 9                0                1                      0
# 10               0                1                      0
# 11               0                1                      0
# 12               0                1                      1
# 13               0                1                      0
# 14               0                1                      0
# 15               0                1                      0
# 16               0                1                      0
# 17               0                1                      0
# 18               1                0                      1
# 19               0                1                      0
# 20               0                1                      0
# 21               0                1                      0
# 22               0                1                      0
# 23               0                1                      0
# 24               0                1                      0
# 25               0                1                      0
# 26               0                1                      0
# 27               0                1                      0
# 28               0                1                      0
# 29               0                1                      0
# 30               0                1                      0
# 31               0                1                      0
# 32               0                1                      0
# 33               0                1                      1
# 34               0                1                      1
# 35               0                1                      0
# 36               1                0                      1
# 37               0                1                      0
# 38               0                1                      0
# 39               0                1                      0
# 40               1                0                      1
# 41               0                1                      0
# 42               0                1                      0
# 43               0                1                      0
# 44               0                1                      1
# 45               0                1                      1
# 46               0                1                      0
# 47               0                1                      0
# 48               0                1                      0
# 49               0                1                      0
# 50               0                1                      0
# 51               0                1                      0
# 52               0                1                      0
# 53               0                1                      0
# 54               0                1                      0
# 55               0                1                      0
# 56               0                1                      0
#
#     disability_support_yes  vacation  dental_plan  health_plan  pension wage1  \
# 0                        1         0            0            0        2     5
# 1                        1         1            0            0        2   4.5
# 3                        1         1            0            0        1   3.7
# 4                        1         0            1            1        2   4.5
# 5                        1         0            0            0        2     2
# 6                        1         2            2            1        0     4
# 7                        1         1            0            0        1   6.9
# 8                        1         1            1            1        1     3
# 9                        1         2            0            0        0   5.7
# 10                       1         2            0            0        0   3.5
# 11                       1         1            0            0        1   6.4
# 12                       0         1            1            1        1   3.5
# 13                       1         2            0            0        0   3.5
# 14                       1         2            0            0        0     3
# 15                       1         0            0            0        0   4.5
# 16                       1         1            0            0        1   2.8
# 17                       1         1            1            2        2   2.1
# 18                       0         0            2            2        1     2
# 19                       1         2            0            0        0     4
# 20                       1         2            0            0        0   4.3
# 21                       1         1            0            0        1   2.5
# 22                       1         1            0            0        1   3.5
# 23                       1         2            1            0        0   4.5
# 24                       1         2            0            0        0     6
# 25                       1         1            1            0        1     2
# 26                       1         1            2            1        1   4.5
# 27                       1         2            0            0        0     3
# 28                       1         1            0            0        1     5
# 29                       1         0            0            0        1     2
# 30                       1         0            1            1        2   4.5
# 31                       1         1            1            0        1     3
# 32                       1         0            0            0        0   2.5
# 33                       0         1            2            2        1     4
# 34                       0         1            1            0        1     2
# 35                       1         0            2            0        1     2
# 36                       0         2            2            2        2     2
# 37                       1         1            1            2        0   2.8
# 38                       1         0            2            2        0     2
# 39                       1         0            0            1        2   4.5
# 40                       0         0            2            2        1     4
# 41                       1         2            2            0        0     2
# 42                       1         0            0            0        0   2.5
# 43                       1         1            0            0        1   2.5
# 44                       0         1            2            2        1     4
# 45                       0         1            1            1        1   4.5
# 46                       1         0            0            0        2   4.5
# 47                       1         1            1            1        1   4.6
# 48                       1         1            0            0        1     5
# 49                       1         0            0            0        2   5.7
# 50                       1         1            0            0        1     7
# 51                       1         1            1            1        0     2
# 52                       1         2            0            0        0   3.5
# 53                       1         0            0            0        0     4
# 54                       1         2            0            0        0     5
# 55                       1         0            1            1        2     5
# 56                       1         2            0            0        0     6
#
#    wage2 wage3  shift_differential  holidays
# 0      0     0                 2.0      11.0
# 1    5.8     0                 4.0      11.0
# 3      4     5                 4.0      11.0
# 4    4.5     5                 4.0      12.0
# 5    2.5     0                 6.0      12.0
# 6      5     5                 4.0      12.0
# 7    4.8   2.3                 3.0      12.0
# 8      7     0                25.0      11.0
# 9      0     0                 4.0      11.0
# 10     4   4.6                 3.0      13.0
# 11   6.4     0                 4.0      15.0
# 12     4     0                 2.0      10.0
# 13     4   5.1                 4.0      13.0
# 14     0     0                10.0      11.0
# 15     4     0                 4.0      11.0
# 16     0     0                 2.0      12.0
# 17     0     0                 3.0       9.0
# 18     0     0                 4.0      11.0
# 19     5     0                 5.0      15.0
# 20   4.4     0                 4.0      12.0
# 21     3     0                 4.0      11.0
# 22     4   4.6                 4.0      11.0
# 23     4     0                 4.0      10.0
# 24     0     0                 3.0       9.0
# 25     2     2                 4.0      10.0
# 26   4.5     0                 4.0      10.0
# 27     3     0                 4.0      12.0
# 28     4     0                 5.0      11.0
# 29   2.5     0                 4.0      10.0
# 30   4.5     5                 4.0      11.0
# 31     2   2.5                 5.0      10.0
# 32   2.5     0                 4.0      10.0
# 33     5     0                 3.0      10.0
# 34   2.5   2.1                 1.0      10.0
# 35     2     0                 4.0      11.0
# 36     0     0                 0.0      11.0
# 37     0     0                 3.0       9.0
# 38   2.5     2                 4.0      10.0
# 39     4     0                 4.0      12.0
# 40     0     0                 4.0      11.0
# 41     3     0                 4.0      12.0
# 42   2.5     0                 4.0      12.0
# 43     3     0                 4.0      11.0
# 44     4     0                 3.0      10.0
# 45     4     0                 2.0      10.0
# 46     4     0                 5.0      11.0
# 47   4.6     0                 4.0      11.0
# 48   4.5     0                 5.0      11.0
# 49   4.5     0                 4.0      11.0
# 50   5.3     0                 4.0      11.0
# 51     3     0                 4.0      11.0
# 52     4   4.5                 4.0      13.0
# 53   3.5     0                 6.0      11.0
# 54   4.4     0                 6.0      11.0
# 55     5     5                 4.0      12.0
# 56     6     4                14.0       9.0

# %%
param_grid = [(10,5),(8,7),(8,2),(10,4)]
for i in range(0,len(param_grid)):
    outer_cv = StratifiedKFold(n_splits=8, shuffle=True, random_state=i)
    mclf = MLPClassifier(solver='lbfgs', random_state=i,hidden_layer_sizes = param_grid[i])
    print (cross_val_score(mclf, X=train, y=_class_distribution, cv=outer_cv).mean())
# Out:
# 0.8125
# 0.848958333333
# 0.645833333333
# 0.859375

# %% [markdown]
# ### Conclusion: the highest testing accuracy in this case is 10 nodes for input layers and 4 nodes for hidden layers.
